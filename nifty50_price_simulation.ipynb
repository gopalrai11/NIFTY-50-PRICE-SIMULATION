# %% [markdown]
# # Simulating Reliance stock price dynamics using Geometric brownian motion

# %%
pip install nsepy
# Out:
# Requirement already satisfied: nsepy in c:\users\gopal\anaconda3\lib\site-packages (0.8)
# Requirement already satisfied: six in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (1.15.0)
# Requirement already satisfied: click in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (7.1.2)
# Requirement already satisfied: numpy in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (1.20.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (4.9.3)
# Requirement already satisfied: lxml in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (4.6.3)
# Requirement already satisfied: requests in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (2.25.1)
# Requirement already satisfied: pandas in c:\users\gopal\anaconda3\lib\site-packages (from nsepy) (1.2.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gopal\anaconda3\lib\site-packages (from beautifulsoup4->nsepy) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gopal\anaconda3\lib\site-packages (from pandas->nsepy) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gopal\anaconda3\lib\site-packages (from pandas->nsepy) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gopal\anaconda3\lib\site-packages (from requests->nsepy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gopal\anaconda3\lib\site-packages (from requests->nsepy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\gopal\anaconda3\lib\site-packages (from requests->nsepy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gopal\anaconda3\lib\site-packages (from requests->nsepy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade git+https://github.com/StreamAlpha/pynse.git
# Out:
# Collecting git+https://github.com/StreamAlpha/pynse.git
#   Cloning https://github.com/StreamAlpha/pynse.git to c:\users\gopal\appdata\local\temp\pip-req-build-tnvgo_v6
# Requirement already satisfied: requests in c:\users\gopal\anaconda3\lib\site-packages (from pynse==0.1.5) (2.25.1)
# Requirement already satisfied: bs4 in c:\users\gopal\anaconda3\lib\site-packages (from pynse==0.1.5) (0.0.1)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/StreamAlpha/pynse.git 'C:\Users\gopal\AppData\Local\Temp\pip-req-build-tnvgo_v6'
# Requirement already satisfied: pandas in c:\users\gopal\anaconda3\lib\site-packages (from pynse==0.1.5) (1.2.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\gopal\anaconda3\lib\site-packages (from pynse==0.1.5) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gopal\anaconda3\lib\site-packages (from beautifulsoup4->pynse==0.1.5) (2.2.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gopal\anaconda3\lib\site-packages (from pandas->pynse==0.1.5) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\gopal\anaconda3\lib\site-packages (from pandas->pynse==0.1.5) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gopal\anaconda3\lib\site-packages (from pandas->pynse==0.1.5) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\gopal\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->pynse==0.1.5) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gopal\anaconda3\lib\site-packages (from requests->pynse==0.1.5) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gopal\anaconda3\lib\site-packages (from requests->pynse==0.1.5) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\gopal\anaconda3\lib\site-packages (from requests->pynse==0.1.5) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gopal\anaconda3\lib\site-packages (from requests->pynse==0.1.5) (1.26.4)

# %%
import pandas as pd
import numpy as np

# %%
from pynse import *
import datetime as dt
import logging
logging.basicConfig(level=logging.DEBUG)


nse=Nse()
print(nse)
# Out:
# INFO:pynse.core:pyNse cache size: (7.09, 'MB').
# You may want to run `nse.clear_data()` if running low on disk space.
# <pynse.core.Nse object at 0x000001803055FC70>

# %%
df=nse.get_hist('Nifty 50',from_date=dt.date(2021,1,1),to_date=dt.date(2022,4,21))
df.head()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40254
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www1.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www1.nseindia.com:443 "GET /products/dynaContent/equities/indices/historicalindices.jsp?indexType=NIFTY%2050&fromDate=01-01-2021&toDate=11-04-2021 HTTP/1.1" 200 5032
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40258
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www1.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www1.nseindia.com:443 "GET /products/dynaContent/equities/indices/historicalindices.jsp?indexType=NIFTY%2050&fromDate=12-04-2021&toDate=21-07-2021 HTTP/1.1" 200 5168
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40247
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www1.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www1.nseindia.com:443 "GET /products/dynaContent/equities/indices/historicalindices.jsp?indexType=NIFTY%2050&fromDate=22-07-2021&toDate=30-10-2021 HTTP/1.1" 200 5193
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40250
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www1.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www1.nseindia.com:443 "GET /products/dynaContent/equities/indices/historicalindices.jsp?indexType=NIFTY%2050&fromDate=31-10-2021&toDate=08-02-2022 HTTP/1.1" 200 5197
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www1.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www1.nseindia.com:443 "GET /products/dynaContent/equities/indices/historicalindices.jsp?indexType=NIFTY%2050&fromDate=09-02-2022&toDate=21-04-2022 HTTP/1.1" 200 3834
#                 Open      High       Low     Close  SharesTraded  Turnover(Cr)
# Date
# 2021-01-01  13996.10  14049.85  13991.35  14018.50   258090905.0      15873.75
# 2021-01-04  14104.35  14147.95  13953.75  14132.90   494999295.0      28705.09
# 2021-01-05  14075.15  14215.60  14048.15  14199.50   492475349.0      30872.87
# 2021-01-06  14240.95  14244.15  14039.90  14146.25   632323316.0      34615.55
# 2021-01-07  14253.75  14256.25  14123.10  14137.35   559173512.0      33446.47

# %%
import matplotlib.pyplot as plt

# %%
adj_close = df['Close']
returns = adj_close.pct_change().dropna()

ax = returns.plot()
ax.set_title( 'NIfty50 returns: {2021,1,1} - {2022,04,14}', 
             fontsize=16)

plt.tight_layout()
plt.show()

print(f'Average return: {100 * returns.mean():.2f}%')
# Out:
# Average return: 0.07%

# %%
train = returns['2021-01-01':'2021-08-31']
test = returns['2021-09-01':'2022-04-21']

# %%
T = len(test)
N = len(test)
s_0 = adj_close[train.index[-1]]
N_SIM = 100
mu = train.mean()
sigma = train.std()

# %%
def simulate_gbm(s_0, mu, sigma, n_sims, T, N, 
                random_seed=42):
    '''
    Function used for simulating stock returns using Geometric Brownian Motion.
    
    Parameters
    ------------
    s_0 : float
    Initial stock price
    mu : float
    Drift coefficient
    sigma : float
    Diffusion coefficient
    n_sims : int
    Number of simulations paths
    dt : float
    Time increment, most commonly a day
    T : float
    Length of the forecast horizon, same unit as dt
    N : int
    Number of time increments in the forecast horizon
    random_seed : int
    Random seed for reproducibility
    
    Returns
    -----------
    S_t : np.ndarray
    Matrix (size: n_sims x (T+1)) containing the simulation results. 
    Rows respresent sample paths, while columns point of time.
    '''''
    np.random.seed(random_seed)
    
    dt = T/N
    dW = np.random.normal(scale = np.sqrt(dt), size=(n_sims, N))
    W = np.cumsum(dW, axis=1)
    
    time_step = np.linspace(dt, T, N)
    time_steps = np.broadcast_to(time_step, (n_sims, N))
    
    S_t = s_0 * np.exp((mu - 0.5 * sigma**2) * time_steps 
                      + sigma * W)
    S_t = np.insert(S_t, 0, s_0, axis=1)
    
    return S_t

# %%
gbm_simulations = simulate_gbm(s_0, mu, sigma, N_SIM, T, N)

# %%
# prepare objects for plotting 
last_train_date = train.index[-1].date()
first_test_date = test.index[0].date()
last_test_date = test.index[-1].date()
plot_title = ('NIfty50 Simulation: {2021,1,1} - {2022,04,14}')

selected_indices = adj_close[last_train_date:last_test_date].index
index = [date.date() for date in selected_indices]

gbm_simulations_df = pd.DataFrame(np.transpose(gbm_simulations), 
                                 index=index)

# plotting
ax = gbm_simulations_df.plot(alpha=0.2, legend=False)
line_1, = ax.plot(index, gbm_simulations_df.mean(axis=1), 
                 color='red')
line_2, = ax.plot(index, adj_close[last_train_date:last_test_date], 
                 color='blue')
ax.set_title(plot_title, fontsize=16)
ax.legend((line_1, line_2), ('mean', 'actual'))

plt.tight_layout()
plt.show()
